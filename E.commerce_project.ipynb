# %%
import pandas as pd 
import plotly.express as px
import plotly.graph_objects as go 
import plotly.io as pio
import plotly.colors as colours 
pio.templates.default = "plotly_white"

# %%
data = pd.read_csv("Sample - Superstore.csv", encoding = 'latin-1')

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Converting_data columns

# %%
data['Order Date'] =pd.to_datetime(data['Order Date'])
data['Ship Date'] =pd.to_datetime(data['Ship Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data['Order Month'] = data['Order Date'].dt.month
data['Order Year'] = data['Order Date'].dt.year
data['Order Day of Week'] = data['Order Date'].dt.dayofweek

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %% [markdown]
# # Monthly Sales Analysis

# %%
sales_by_month = data.groupby('Order Month')['Sales'].sum().reset_index()
fig = px.line(sales_by_month,
              x='Order Month',
              y='Sales',
              title ='Monthly Sales Analysis')
fig.show()

# %% [markdown]
# #The Highest sales were recorded in Month November.
# #The Lowest sales were observerd in Month February.

# %% [markdown]
# # Sales by Category

# %%
sales_by_category = data.groupby('Category')['Sales'].sum().reset_index()
fig = px.pie(sales_by_category,
             values = 'Sales',
             names = 'Category',
             hole = 0.2,
             color_discrete_sequence=px.colors.qualitative.Pastel)


fig.update_traces(textposition = 'inside',textinfo ='percent+label')
fig.update_layout(title_text= 'Sales Analysis by Category',title_font = dict(size = 24))
fig.show()

# %% [markdown]
# Technology category has the highest sales contribution at 36.4%
# Furniture and offices Supplies follow closely with 32.3% and 31.3% respectively

# %% [markdown]
# # Sales Analysis by sub category

# %%
sales_by_subcategory = data.groupby('Sub-Category')['Sales'].sum().reset_index()
fig = px.bar(sales_by_subcategory,x='Sub-Category',y = 'Sales', title ="Sales analysis by sub - category")
fig.show()

# %% [markdown]
# Phone and chairs highest sales in sub - categories

# %% [markdown]
# # Monthly Profit Analysis

# %%
profit_by_month = data.groupby('Order Month')['Profit'].sum().reset_index()

# %%
fig =px.line(profit_by_month,x = 'Order Month',y = 'Profit', title ='Monthly_Profit_Analysis')
fig.show()

# %% [markdown]
# December Has the Highest Profit Month

# %% [markdown]
# # Profit by Category

# %%
profit_by_category = data.groupby('Category')['Profit'].sum().reset_index()
fig = px.pie(profit_by_category,
             values = 'Profit',
             names = 'Category',
             hole = 0.2,
             color_discrete_sequence=px.colors.qualitative.Pastel)


fig.update_traces(textposition = 'inside',textinfo ='percent+label')
fig.update_layout(title_text= 'Profit Analysis by Category',title_font = dict(size = 24))
fig.show()

# %%
profit_by_subcategory = data.groupby('Sub-Category')['Profit'].sum().reset_index()
fig = px.bar(profit_by_subcategory,x='Sub-Category',y = 'Profit', title ="Profit analysis by sub_category")
fig.show()

# %% [markdown]
# The Copiers sub- category shows the highest profit as highlighted in graph

# %% [markdown]
# # Sales and profit customer segment

# %%
sales_profit_by_segment = data.groupby('Segment').agg({'Sales':'sum','Profit':'sum'}).reset_index()
color_palette = px.colors.qualitative.Pastel

fig = go.Figure()
fig.add_trace(go.Bar(x=sales_profit_by_segment['Segment'],
                     y=sales_profit_by_segment['Sales'],
                     name = 'Sales',
                     marker_color = color_palette[0]))

fig.add_trace(go.Bar(x=sales_profit_by_segment['Segment'],
                     y=sales_profit_by_segment['Profit'],
                     name = 'Profit',
                     marker_color = color_palette[1]))
fig.update_layout(title = 'Sales and Profit Analysis by Customer Segment',
                  xaxis_title = 'Customer Segment',yaxis_title='Amount')
fig.show()

# %% [markdown]
# # Sales to profit ratio

# %%
sales_profit_by_segment = data.groupby('Segment').agg({'Sales':'sum','Profit':'sum'}).reset_index()
sales_profit_by_segment['Sales_to_Profit_Ratio'] = sales_profit_by_segment['Sales']/sales_profit_by_segment['Profit']
print(sales_profit_by_segment [['Sales_to_Profit_Ratio']])
# Out:
#    Sales_to_Profit_Ratio
# 0               8.659471
# 1               7.677245
# 2               7.125416

# %% [markdown]
# ---
#
# ## 📝 Summary & Conclusion
#
# This analysis explored the **Superstore dataset** containing **9,994 transactions** across the United States from **2014 to 2017**.
#
# ---
#
# ### 🔑 Key Findings
#
# **1. Monthly Sales Trend**
# - Sales peak in **November** ($352K) and are lowest in **February** ($60K).
# - The last quarter (October–December) consistently drives the highest revenue.
#
# **2. Category Performance**
# - **Technology** is the strongest category — highest in both sales ($836K) and profit ($145K).
# - **Furniture** has high sales ($742K) but very low profit ($18K) — only a 2.5% margin.
#
# **3. Sub-Category Insights**
# - Top profit makers: **Copiers, Phones, and Accessories**.
# - Loss-making sub-categories: **Tables (−$17,725), Bookcases (−$3,473), and Supplies (−$1,189)**.
#
# **4. Customer Segments**
# - The **Consumer segment** contributes the most — 50.6% of total sales ($1.16M).
# - All three segments (Consumer, Corporate, Home Office) are profitable.
#
# **5. Discount Impact**
# - Discounts up to 20% are safe and generate positive profit.
# - Discounts **above 20%** result in **negative average profit** per order — a major business risk.
#
# ---
#
# ### ✅ Business Recommendations
#
# 1. **Cap discounts at 20%** to avoid profit losses.
# 2. **Investigate Furniture pricing** — especially Tables which is losing money.
# 3. **Focus marketing in Q4** — November and December are the best months.
# 4. **Invest more in Technology products** — they give the best return.
# 5. **Launch loyalty programs** for the Consumer segment to retain the top revenue source.
#
# ---
#
# ### 🛠️ Tools Used
# - **Python** — Programming language
# - **Pandas** — Data loading and manipulation
# - **Plotly** — Interactive visualizations
#
# ---
# *Analysis by Abhinna Singh  | Dataset: Sample Superstore | Period: 2014–2017*
